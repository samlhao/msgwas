# %%
import scanpy as sc
import numpy as np
import pandas as pd
import os

# %%
os.chdir("/home/shao11/data_kfitzg13/msgwas_shao11")

# %%
schafflick = sc.read_h5ad("data/sc_data/pbmc/schafflick/processed/MS_CSF.h5ad")

# %%
schafflick
# Out:
# AnnData object with n_obs × n_vars = 65326 × 10266
#     obs: 'labels', 'MS', 'CSF', 'valid_clusters', 'CD4_labels'
#     obsm: 'X_umap'

# %%
schafflick.obs
# Out:
#        labels     MS    CSF valid_clusters CD4_labels
# 0        Gran  False   True           True         -1
# 1         CD4  False   True           True          6
# 2         CD4  False   True           True          1
# 3      ncMono  False   True           True         -1
# 4         CD4  False   True           True          2
# ...       ...    ...    ...            ...        ...
# 65321     RBC  False  False          False         -1
# 65322    CD8a  False  False           True         -1
# 65323     RBC  False  False          False         -1
# 65324    CD8n  False  False           True         -1
# 65325     RBC  False  False          False         -1
#
# [65326 rows x 5 columns]

# %%
pbmc = schafflick[schafflick.obs.CSF == "False"]

# %%
pbmc.to_df()
# Out:
#        FO538757.2  AP006222.2  RP11-206L10.9  FAM41C     NOC2L  PLEKHN1  \
# 22357         0.0    0.000000            0.0     0.0  1.575748      0.0
# 22358         0.0    0.000000            0.0     0.0  0.000000      0.0
# 22359         0.0    0.000000            0.0     0.0  0.000000      0.0
# 22360         0.0    0.000000            0.0     0.0  0.000000      0.0
# 22361         0.0    0.000000            0.0     0.0  0.000000      0.0
# ...           ...         ...            ...     ...       ...      ...
# 65321         0.0    0.000000            0.0     0.0  0.000000      0.0
# 65322         0.0    1.507665            0.0     0.0  0.000000      0.0
# 65323         0.0    0.000000            0.0     0.0  0.000000      0.0
# 65324         0.0    0.000000            0.0     0.0  0.000000      0.0
# 65325         0.0    0.000000            0.0     0.0  0.000000      0.0
#
#          ISG15  TNFRSF18  TNFRSF4  SDF4  ...    MT-CO3    MT-ND3   MT-ND4L  \
# 22357  2.15972       0.0      0.0   0.0  ...  3.672332  3.928814  0.000000
# 22358  0.00000       0.0      0.0   0.0  ...  3.739683  3.777989  1.455534
# 22359  0.00000       0.0      0.0   0.0  ...  3.864967  2.539665  1.922453
# 22360  0.00000       0.0      0.0   0.0  ...  4.219682  3.448715  0.000000
# 22361  0.00000       0.0      0.0   0.0  ...  3.802824  2.958108  0.000000
# ...        ...       ...      ...   ...  ...       ...       ...       ...
# 65321  0.00000       0.0      0.0   0.0  ...  0.000000  0.000000  0.000000
# 65322  0.00000       0.0      0.0   0.0  ...  3.485709  3.588002  2.083477
# 65323  0.00000       0.0      0.0   0.0  ...  0.000000  0.000000  0.000000
# 65324  0.00000       0.0      0.0   0.0  ...  3.870781  3.542611  1.471486
# 65325  0.00000       0.0      0.0   0.0  ...  0.000000  0.000000  0.000000
#
#          MT-ND4    MT-ND5    MT-ND6    MT-CYB  AL592183.1  AC004556.1  \
# 22357  3.765329  1.575748  0.000000  3.765329         0.0     0.00000
# 22358  3.699850  2.649508  0.000000  2.649508         0.0     0.97206
# 22359  3.407463  2.539665  0.000000  3.192567         0.0     0.00000
# 22360  3.233487  1.397727  1.397727  3.233487         0.0     0.00000
# 22361  3.881150  1.537362  0.000000  3.522551         0.0     0.00000
# ...         ...       ...       ...       ...         ...         ...
# 65321  0.000000  0.000000  0.000000  0.000000         0.0     0.00000
# 65322  4.216670  3.095444  0.000000  4.163422         0.0     0.00000
# 65323  0.000000  0.000000  0.000000  0.000000         0.0     0.00000
# 65324  3.050894  1.471486  0.000000  3.720098         0.0     0.00000
# 65325  0.000000  0.000000  0.000000  0.000000         0.0     0.00000
#
#        AC240274.1
# 22357         0.0
# 22358         0.0
# 22359         0.0
# 22360         0.0
# 22361         0.0
# ...           ...
# 65321         0.0
# 65322         0.0
# 65323         0.0
# 65324         0.0
# 65325         0.0
#
# [42969 rows x 10266 columns]
